# %%
import polars as pl
pl.Config.set_tbl_rows(20)
pl.Config.set_fmt_str_lengths(60)
pl.Config.set_tbl_width_chars(200)
# Out:
# polars.config.Config

# %%
quality_check1 = pl.read_parquet("./quality_check1.parquet")
quality_check2 = pl.read_parquet("./quality_check2.parquet")
quality_check3 = pl.read_parquet("./Quality_Topic_extract.parquet")

# %%
tables = {
    "df1":    quality_check1,
    "df2":    quality_check2,
    "df3":    quality_check3
}

# %%
print(f"{'Table':<15} {'Lignes':>8} {'Colonnes':>10} {'Nulls total':>14} {'Str cols':>10} {'Num cols':>10}")
for name, df in tables.items():
    n_rows    = df.shape[0]
    n_cols    = df.shape[1]
    n_nulls   = sum(df[c].null_count() for c in df.columns)
    n_str     = sum(1 for c in df.columns if df[c].dtype == pl.Utf8)
    n_num     = sum(1 for c in df.columns if df[c].dtype in (pl.Int64, pl.Float64, pl.Int32))
    print(f"{name:<15} {n_rows:>8} {n_cols:>10} {n_nulls:>14} {n_str:>10} {n_num:>10}")
# Out:
# Table             Lignes   Colonnes    Nulls total   Str cols   Num cols
# df1                  129         14              0         14          0
# df2                  115         14              0         14          0
# df3                  262         16            262         15          0

# %%
for name, df in tables.items():
    print(f" {name.upper()}")
    display(df.head())
# Out:
#  DF1
# shape: (5, 14)
# ┌─────────────────┬──────────────────────┬──────────────────────┬─────────────────────────────┬───┬─────────────────────┬─────────┬─────────┬─────────────┐
# │ applicationCode ┆ controlledObjectName ┆ controlledObjectType ┆ controlledsourceName        ┆ … ┆ controlledItemCount ┆ okCount ┆ koCount ┆ controlTool │
# │ ---             ┆ ---                  ┆ ---                  ┆ ---                         ┆   ┆ ---                 ┆ ---     ┆ ---     ┆ ---         │
# │ str             ┆ str                  ┆ str                  ┆ str                         ┆   ┆ str                 ┆ str     ┆ str     ┆ str         │
# ╞═════════════════╪══════════════════════╪══════════════════════╪═════════════════════════════╪═══╪═════════════════════╪═════════╪═════════╪═════════════╡
# │ mkd             ┆                      ┆ FIELD                ┆ s_japt_jal_publication_type ┆ … ┆ 852                 ┆ 852     ┆ 0       ┆ CDQ         │
# │ mkd             ┆                      ┆ FIELD                ┆ s_japt_jal_publication_type ┆ … ┆ 852                 ┆ 852     ┆ 0       ┆ CDQ         │
# │ mkd             ┆                      ┆ FIELD                ┆ s_japt_jal_publication_type ┆ … ┆ 852                 ┆ 852     ┆ 0       ┆ CDQ         │
# │ mkd             ┆                      ┆ FIELD                ┆ s_japt_jal_publication_type ┆ … ┆ 852                 ┆ 852     ┆ 0       ┆ CDQ         │
# │ mkd             ┆                      ┆ FIELD                ┆ s_comp_company              ┆ … ┆ 12716               ┆ 12716   ┆ 10351   ┆ CDQ         │
# └─────────────────┴──────────────────────┴──────────────────────┴─────────────────────────────┴───┴─────────────────────┴─────────┴─────────┴─────────────┘
#  DF2
# shape: (5, 14)
# ┌─────────────────┬──────────────────────┬──────────────────────┬────────────────────────────────┬───┬─────────────────────┬─────────┬─────────┬─────────────┐
# │ applicationCode ┆ controlledObjectName ┆ controlledObjectType ┆ controlledsourceName           ┆ … ┆ controlledItemCount ┆ okCount ┆ koCount ┆ controlTool │
# │ ---             ┆ ---                  ┆ ---                  ┆ ---                            ┆   ┆ ---                 ┆ ---     ┆ ---     ┆ ---         │
# │ str             ┆ str                  ┆ str                  ┆ str                            ┆   ┆ str                 ┆ str     ┆ str     ┆ str         │
# ╞═════════════════╪══════════════════════╪══════════════════════╪════════════════════════════════╪═══╪═════════════════════╪═════════╪═════════╪═════════════╡
# │ mkd             ┆                      ┆ FIELD                ┆ s_japt_jal_publication_type    ┆ … ┆ 852                 ┆ 852     ┆ 0       ┆ CDQ         │
# │ mkd             ┆                      ┆ FIELD                ┆ s_labo_last_business_owner     ┆ … ┆ 2181434             ┆ 2181434 ┆ 0       ┆ CDQ         │
# │ mkd             ┆                      ┆ FIELD                ┆ s_labo_last_business_owner     ┆ … ┆ 2181434             ┆ 2181434 ┆ 0       ┆ CDQ         │
# │ mkd             ┆                      ┆ FIELD                ┆ s_labo_last_business_owner     ┆ … ┆ 2181434             ┆ 2181434 ┆ 0       ┆ CDQ         │
# │ mkd             ┆                      ┆ FIELD                ┆ s_labj_last_business_owner_jal ┆ … ┆ 120                 ┆ 120     ┆ 0       ┆ CDQ         │
# └─────────────────┴──────────────────────┴──────────────────────┴────────────────────────────────┴───┴─────────────────────┴─────────┴─────────┴─────────────┘
#  DF3
# shape: (5, 16)
# ┌─────────────────┬────────────────────────────────┬──────────────────────┬────────────────────────────────┬───┬─────────┬─────────────┬───────────────────────────────┬───────────────────────────────┐
# │ applicationcode ┆ controlledobjectname           ┆ controlledobjecttype ┆ controlledsourcename           ┆ … ┆ kocount ┆ controltool ┆ cdqprofile                    ┆ controllink                   │
# │ ---             ┆ ---                            ┆ ---                  ┆ ---                            ┆   ┆ ---     ┆ ---         ┆ ---                           ┆ ---                           │
# │ str             ┆ str                            ┆ str                  ┆ str                            ┆   ┆ str     ┆ str         ┆ str                           ┆ str                           │
# ╞═════════════════╪════════════════════════════════╪══════════════════════╪════════════════════════════════╪═══╪═════════╪═════════════╪═══════════════════════════════╪═══════════════════════════════╡
# │ ESG             ┆ [ecin_energy_consumption_infor ┆ Table                ┆ ecin_energy_consumption_inform ┆ … ┆ 0       ┆ CDQ         ┆ Profil_ESG_ecin_energy_consum ┆ https://cdgc.dm-em.informatic │
# │                 ┆ mation_vw.climatequestionnaire ┆                      ┆ ation_vw                       ┆   ┆         ┆             ┆ ption_information_vw          ┆ acloud.com/asset/2e858e3f-91d │
# │                 ┆ …                              ┆                      ┆                                ┆   ┆         ┆             ┆                               ┆ 2-…                           │
# │ ESG             ┆ [nfin_non_financial_informatio ┆ Table                ┆ nfin_non_financial_information ┆ … ┆ 0       ┆ CDQ         ┆ Profile_ESG_nfin_non_financia ┆ https://cdgc.dm-em.informatic │
# │                 ┆ n_vw.climatequestionnaireid]   ┆                      ┆ _vw                            ┆   ┆         ┆             ┆ l_information                 ┆ acloud.com/asset/2fca5389-e41 │
# │                 ┆                                ┆                      ┆                                ┆   ┆         ┆             ┆                               ┆ 1-…                           │
# │ ESG             ┆ [eias_esginvest_association_vw ┆ Table                ┆ eias_esginvest_association_vw  ┆ … ┆ 0       ┆ CDQ         ┆ Profil_ESG_eias_esginvest_ass ┆ https://cdgc.dm-em.informatic │
# │                 ┆ .organisationpartyid]          ┆                      ┆                                ┆   ┆         ┆             ┆ ociation_vw                   ┆ acloud.com/asset/39b7cff5-846 │
# │                 ┆                                ┆                      ┆                                ┆   ┆         ┆             ┆                               ┆ 0-…                           │
# │ mkd             ┆ [s_comp_company.d_regis]       ┆ Table                ┆ s_comp_company                 ┆ … ┆ 9134    ┆ CDQ         ┆ profile_mkd_mom_s_comp_compan ┆ https://cdgc.dm-em.informatic │
# │                 ┆                                ┆                      ┆                                ┆   ┆         ┆             ┆ y_altares                     ┆ acloud.com/asset/fec87685-47b │
# │                 ┆                                ┆                      ┆                                ┆   ┆         ┆             ┆                               ┆ c-…                           │
# │ ESG             ┆ [DIFF_gepe_governance_environm ┆ Table                ┆ DIFF_gepe_governance_environme ┆ … ┆ 0       ┆ CDQ         ┆ Profil_ESG_DIFF_gepe_governan ┆ https://cdgc.dm-em.informatic │
# │                 ┆ ental_performance_vw_topic.cli ┆                      ┆ ntal_performance_vw_topic      ┆   ┆         ┆             ┆ ce_environmental_performance  ┆ acloud.com/asset/737c0c62-2d5 │
# │                 ┆ …                              ┆                      ┆                                ┆   ┆         ┆             ┆                               ┆ d-…                           │
# └─────────────────┴────────────────────────────────┴──────────────────────┴────────────────────────────────┴───┴─────────┴─────────────┴───────────────────────────────┴───────────────────────────────┘
